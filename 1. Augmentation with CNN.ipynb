# %% [markdown]
# # Imports

# %%
import numpy as np 
import pandas as pd 
import os

import matplotlib.pyplot as plt
import csv
import itertools
import collections

import pywt
from scipy import stats
from sklearn.metrics import classification_report
from sklearn.utils import resample
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.layers import Conv1D, AvgPool1D, Flatten, Dense, Dropout, Softmax
from keras.optimizers import Adam 
from keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from keras import regularizers


# %matplotlib inline
# Out:
# 2023-08-24 15:22:09.866615: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-24 15:22:09.867932: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-24 15:22:09.894974: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-24 15:22:09.895514: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-24 15:22:10.378242: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Matplotlib settings

# %%
plt.rcParams["figure.figsize"] = (30,6)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.color'] = 'b'
plt.rcParams['axes.grid'] = True

# %% [markdown]
# # Methods Definitions

# %%
def denoise(data): 
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))
        
    datarec = pywt.waverec(coeffs, 'sym4')
    
    return datarec

# %% [markdown]
# # Variables Definitions

# %%
path = '/home/faze_vennom/BTP/mitbih_database/mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# %% [markdown]
# # Prepare Input Files

# %%
# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt 
records = list()
annotations = list()
filenames.sort()

# %%
# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)
    
    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %% [markdown]
# # Data extraction and preprocessing

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1
            
    # Plot an example to the signals
    if r == 6:
        # Plot each patient's signal
        plt.title(records[6] + " Wave")
        plt.plot(signals[0:700])
        plt.show()
        
    signals = denoise(signals)
    # Plot an example to the signals
    if r == 6:
        # Plot each patient's signal
        plt.title(records[6] + " wave after denoised")
        plt.plot(signals[0:700])
        plt.show()
        
    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r == 6:
        # Plot each patient's signal
        plt.title(records[6] + " wave after z-score normalization ")
        plt.plot(signals[0:700])
        plt.show()
    
    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines() 
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ') #The split() method splits a string into a list.
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
           # if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
                #    pass
            #else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat    
                    if r == 6 and not example_beat_printed: 
                        plt.title("A Beat from " + records[6] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# (100012, 360) (100012,)

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])
#         X[i].append(y[i])

print(np.shape(X))
# Out:
# (100012, 361)

# %% [markdown]
# # Classes Distribution

# %%
X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(30,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 360
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: count, dtype: int64

# %% [markdown]
# # Rebalancing Classes
# ## Addressing Class Imbalance in Micro ECG Classification
# Class imbalance in a database of arrhythmia occurs when the number of samples in different arrhythmia types is significantly different. It needs to be addressed because it can lead to biased model training, reduced sensitivity, misleading evaluation metrics.
#
# Various techniques can be used for addressing class imbalance during data preprocessing and model training stages:
#
# Oversampling the Minority Class: This involves creating duplicate samples of the minority class.
# Undersampling the Majority Class: In this approach, some samples from the majority class are randomly removed.
# Synthetic Data Generation: Using techniques like SMOTE to generate synthetic samples for the minority class.
# Cost-Sensitive Learning: Assigning different misclassification costs during model training.
# Ensemble Methods: Utilizing ensemble models like AdaBoost or XGBoost.
# Performance Metrics: Choosing appropriate evaluation metrics like precision, recall, F1-score, or AUC-ROC.
# The choice of rebalancing technique depends on the dataset, model, and specific problem at hand. Careful experimentation is essential.

# %%
df_1=X_train_df[X_train_df[X_train_df.shape[1]-1]==1]
df_2=X_train_df[X_train_df[X_train_df.shape[1]-1]==2]
df_3=X_train_df[X_train_df[X_train_df.shape[1]-1]==3]
df_4=X_train_df[X_train_df[X_train_df.shape[1]-1]==4]
# df_5=X_train_df[X_train_df[X_train_df.shape[1]-1]==5]
df_0=(X_train_df[X_train_df[X_train_df.shape[1]-1]==0]).sample(n=5000,random_state=42)

df_1_upsample=resample(df_1,replace=True,n_samples=5000,random_state=122)
df_2_upsample=resample(df_2,replace=True,n_samples=5000,random_state=123)
df_3_upsample=resample(df_3,replace=True,n_samples=5000,random_state=124)
df_4_upsample=resample(df_4,replace=True,n_samples=5000,random_state=125)
# df_5_upsample=resample(df_5,replace=True,n_samples=5000,random_state=126)

# X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample,df_5_upsample])
X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample])

# %%
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 360
# 0.0    5000
# 1.0    5000
# 2.0    5000
# 3.0    5000
# 4.0    5000
# Name: count, dtype: int64

# %% [markdown]
# # Train - test Data Spliting
# We are keeping 20% data for testing and the rest of the data ffor training

# %%
train, test = train_test_split(X_train_df, test_size=0.20)

print("X_train : ", np.shape(train))
print("X_test  : ", np.shape(test))
# Out:
# X_train :  (20000, 361)
# X_test  :  (5000, 361)

# %%
target_train=train[train.shape[1]-1]
target_test=test[test.shape[1]-1]
train_y=to_categorical(target_train)
test_y=to_categorical(target_test)
print(np.shape(train_y), np.shape(test_y))
# Out:
# (20000, 5) (5000, 5)

# %%
train_x = train.iloc[:,:train.shape[1]-1].values
test_x = test.iloc[:,:test.shape[1]-1].values
train_x = train_x.reshape(len(train_x), train_x.shape[1],1)
test_x = test_x.reshape(len(test_x), test_x.shape[1],1)
print(np.shape(train_x), np.shape(test_x))
# Out:
# (20000, 360, 1) (5000, 360, 1)

# %% [markdown]
# # Building the Model Architecture
#
# 1. Import necessary libraries and modules.
# 2. Instantiate an empty Sequential model.
# 3. Adding 1D convolutional layers (C1, C3, C5, C7) to detect features.
# 4. Adding average pooling layers (S2, S4, S6, S8) to reduce dimensions.
# 5. Flattening the data before dense layers.
# 6. Adding a Dropout layer to prevent overfitting.
# 7. Adding two dense layers (S10, S11) for classification with L2 regularization.
# 8. Adding a softmax layer for probability scores.
# 9. Displaying the model summary.

# %%
# Instanciate an empty model
model = Sequential()

# Adding a Convolution Layer C1
# Input shape = N = (360 x 1)
# No. of filters  = 16
# Filter size = f = (13 x 1)
# Padding = true
# Strides = S = 1
# Size of each feature map in C1 is (N-f+2P)/S +1 = 360-13+2*6 +1 = 360
# No. of parameters between input layer and C1 = (13*1 + 1)*16 = 224
model.add(Conv1D(filters=16, kernel_size=13, padding='same', activation='relu',input_shape=(360, 1)))


# Adding an Average Pooling Layer S2
# Input shape = N = (360 x 16)
# No. of filters = 16
# Filter size = f = (3 x 1)
# Padding = P = 0
# Strides = S = 2
# Size of each feature map in S2 is (N-f+2P+1)/S = (360-3+0+1)/2 = 179
# No. of parameters between C1 and S2 = (1+1)*16 = 32
model.add(AvgPool1D(pool_size=3, strides=2))





# Adding a Convolution Layer C3
# Input shape = N = (179 x 16)
# No. of filters  = 32
# Filter size = f = (15 x 1)
# Padding = true
# Strides = S = 1
# Size of each feature map in C1 is (N-f+2P)/S +1 = 179-15+2*7 +1 = 360
# No. of parameters between input layer and C1 = (15*1 + 1)*32 = 512
model.add(Conv1D(filters=32, kernel_size=15, padding='same', activation='relu'))


# Adding an Average Pooling Layer S4
# Input shape = N = (179 x 32)
# No. of filters = 32
# Filter size = f = (3 x 1)
# Padding = P = 0
# Strides = S = 2
# Size of each feature map in S2 is (N-f+2P+1)/S = (179-3+0+1)/2 = 89
# No. of parameters between C1 and S2 = (1+1)*32 = 64
model.add(AvgPool1D(pool_size=3, strides=2))



# Adding a Convolution Layer C5
# Input shape = N = (89 x 32)
# No. of filters  = 64
# Filter size = f = (17 x 1)
# Padding = true
# Strides = S = 1
# Size of each feature map in C1 is (N-f+2P)/S +1 = 89-17+2*8 +1 = 89
# No. of parameters between input layer and C1 = (17*1 + 1)*64 = 1152
model.add(Conv1D(filters=64, kernel_size=17, padding='same', activation='relu'))



# Adding an Average Pooling Layer S6
# Input shape = N = (89 x 64)
# No. of filters = 64
# Filter size = f = (3 x 1)
# Padding = P = 0
# Strides = S = 2
# Size of each feature map in S2 is (N-f+2P+1)/S = (89-3+0+1)/2 = 44
# No. of parameters between C1 and S2 = (1+1)*64 = 128
model.add(AvgPool1D(pool_size=3, strides=2))



# Adding a Convolution Layer C7
# Input shape = N = (44 x 64)
# No. of filters  = 128
# Filter size = f = (19 x 1)
# Padding = true
# Strides = S = 1
# Size of each feature map in C1 is (N-f+2P)/S +1 = 44-19+2*9 +1 = 44
# No. of parameters between input layer and C1 = (19*1 + 1)*128 = 2560
model.add(Conv1D(filters=128, kernel_size=19, padding='same', activation='relu'))


# Adding an Average Pooling Layer S8
# Input shape = N = (44 x 128)
# No. of filters = 128
# Filter size = f = (3 x 1)
# Padding = P = 0
# Strides = S = 2
# Size of each feature map in S2 is (N-f+2P+1)/S = (44-3+0+1)/2 = 21
# No. of parameters between C1 and S2 = (1+1)*128 = 256
model.add(AvgPool1D(pool_size=3, strides=2))



# Flattening the layer 
# There would be 128*(21*1) = 2688 neurons
model.add(Flatten())


# Dropout the layer S9
model.add(Dropout(0.5))



# Adding a Dense layer with regularization l2(0.0001)# S10
# No. of inputs = 2688
# No. of outputs = 35
# No. of parameters = 2688 x 35 + 35 = 94115
model.add(Dense(35,kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001)))



# Adding a Dense layer with regularization l2(0.0001)# S11
# No. of inputs = 35
# No. of outputs = 5
# No. of parameters = 35*5 + 5 = 180
model.add(Dense(5,kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001)))



# Adding a Softmax layer S12
# No. of inputs = 5
# No. of outputs = 5
model.add(Softmax())


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 360, 16)           224
#
#  average_pooling1d (Average  (None, 179, 16)           0
#  Pooling1D)
#
#  conv1d_1 (Conv1D)           (None, 179, 32)           7712
#
#  average_pooling1d_1 (Avera  (None, 89, 32)            0
#  gePooling1D)
#
#  conv1d_2 (Conv1D)           (None, 89, 64)            34880
#
#  average_pooling1d_2 (Avera  (None, 44, 64)            0
#  gePooling1D)
#
#  conv1d_3 (Conv1D)           (None, 44, 128)           155776
#
#  average_pooling1d_3 (Avera  (None, 21, 128)           0
#  gePooling1D)
#
#  flatten (Flatten)           (None, 2688)              0
#
#  dropout (Dropout)           (None, 2688)              0
#
#  dense (Dense)               (None, 35)                94115
#
#  dense_1 (Dense)             (None, 5)                 180
#
#  softmax (Softmax)           (None, 5)                 0
#
# =================================================================
# Total params: 292887 (1.12 MB)
# Trainable params: 292887 (1.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Compiling the model

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %% [markdown]
# # Fitting the model

# %%
history = model.fit(train_x, train_y, batch_size=36, epochs=100, verbose=1, validation_data=(test_x, test_y))
# Out:
# Epoch 1/100
# 556/556 [==============================] - 6s 11ms/step - loss: 0.0134 - accuracy: 0.9985 - val_loss: 0.1052 - val_accuracy: 0.9914
# Epoch 2/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0101 - accuracy: 0.9994 - val_loss: 0.0849 - val_accuracy: 0.9918
# Epoch 3/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0067 - accuracy: 0.9998 - val_loss: 0.0877 - val_accuracy: 0.9904
# Epoch 4/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0135 - accuracy: 0.9983 - val_loss: 0.0828 - val_accuracy: 0.9922
# Epoch 5/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0109 - accuracy: 0.9987 - val_loss: 0.0988 - val_accuracy: 0.9928
# Epoch 6/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0091 - accuracy: 0.9994 - val_loss: 0.1068 - val_accuracy: 0.9890
# Epoch 7/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0090 - accuracy: 0.9992 - val_loss: 0.0814 - val_accuracy: 0.9924
# Epoch 8/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0077 - accuracy: 0.9992 - val_loss: 0.0861 - val_accuracy: 0.9912
# Epoch 9/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0087 - accuracy: 0.9993 - val_loss: 0.0965 - val_accuracy: 0.9890
# Epoch 10/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0053 - accuracy: 0.9998 - val_loss: 0.0834 - val_accuracy: 0.9912
# Epoch 11/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0135 - accuracy: 0.9979 - val_loss: 0.0825 - val_accuracy: 0.9906
# Epoch 12/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0137 - accuracy: 0.9990 - val_loss: 0.1187 - val_accuracy: 0.9876
# Epoch 13/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0078 - accuracy: 0.9995 - val_loss: 0.0929 - val_accuracy: 0.9914
# Epoch 14/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0052 - accuracy: 0.9999 - val_loss: 0.0940 - val_accuracy: 0.9918
# Epoch 15/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9916
# Epoch 16/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0103 - accuracy: 0.9984 - val_loss: 0.1411 - val_accuracy: 0.9874
# Epoch 17/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0119 - accuracy: 0.9986 - val_loss: 0.0842 - val_accuracy: 0.9894
# Epoch 18/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0105 - accuracy: 0.9989 - val_loss: 0.0942 - val_accuracy: 0.9894
# Epoch 19/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0057 - accuracy: 0.9996 - val_loss: 0.0888 - val_accuracy: 0.9916
# Epoch 20/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0088 - accuracy: 0.9991 - val_loss: 0.0847 - val_accuracy: 0.9912
# Epoch 21/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0146 - accuracy: 0.9981 - val_loss: 0.0881 - val_accuracy: 0.9910
# Epoch 22/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0079 - accuracy: 0.9994 - val_loss: 0.0971 - val_accuracy: 0.9906
# Epoch 23/100
# 556/556 [==============================] - 8s 13ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.0836 - val_accuracy: 0.9918
# Epoch 24/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0092 - accuracy: 0.9988 - val_loss: 0.0859 - val_accuracy: 0.9900
# Epoch 25/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0106 - accuracy: 0.9988 - val_loss: 0.1173 - val_accuracy: 0.9906
# Epoch 26/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0147 - accuracy: 0.9979 - val_loss: 0.0767 - val_accuracy: 0.9922
# Epoch 27/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0138 - accuracy: 0.9983 - val_loss: 0.0989 - val_accuracy: 0.9924
# Epoch 28/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0152 - accuracy: 0.9986 - val_loss: 0.1178 - val_accuracy: 0.9892
# Epoch 29/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0151 - accuracy: 0.9984 - val_loss: 0.0855 - val_accuracy: 0.9914
# Epoch 30/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0085 - accuracy: 0.9995 - val_loss: 0.0941 - val_accuracy: 0.9904
# Epoch 31/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0079 - accuracy: 0.9993 - val_loss: 0.0921 - val_accuracy: 0.9916
# Epoch 32/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0082 - accuracy: 0.9991 - val_loss: 0.0795 - val_accuracy: 0.9914
# Epoch 33/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0118 - accuracy: 0.9987 - val_loss: 0.0826 - val_accuracy: 0.9896
# Epoch 34/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0118 - accuracy: 0.9985 - val_loss: 0.0934 - val_accuracy: 0.9912
# Epoch 35/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0066 - accuracy: 0.9997 - val_loss: 0.0934 - val_accuracy: 0.9898
# Epoch 36/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0071 - accuracy: 0.9995 - val_loss: 0.0820 - val_accuracy: 0.9898
# Epoch 37/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0086 - accuracy: 0.9989 - val_loss: 0.0855 - val_accuracy: 0.9912
# Epoch 38/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0057 - accuracy: 0.9996 - val_loss: 0.0990 - val_accuracy: 0.9900
# Epoch 39/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0167 - accuracy: 0.9975 - val_loss: 0.0900 - val_accuracy: 0.9910
# Epoch 40/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0105 - accuracy: 0.9991 - val_loss: 0.0953 - val_accuracy: 0.9904
# Epoch 41/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0169 - accuracy: 0.9981 - val_loss: 0.1414 - val_accuracy: 0.9876
# Epoch 42/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0144 - accuracy: 0.9986 - val_loss: 0.1063 - val_accuracy: 0.9906
# Epoch 43/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0129 - accuracy: 0.9988 - val_loss: 0.1063 - val_accuracy: 0.9902
# Epoch 44/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0125 - accuracy: 0.9988 - val_loss: 0.1049 - val_accuracy: 0.9900
# Epoch 45/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0075 - accuracy: 0.9996 - val_loss: 0.1092 - val_accuracy: 0.9908
# Epoch 46/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0067 - accuracy: 0.9994 - val_loss: 0.1228 - val_accuracy: 0.9908
# Epoch 47/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0091 - accuracy: 0.9991 - val_loss: 0.0914 - val_accuracy: 0.9900
# Epoch 48/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0139 - accuracy: 0.9983 - val_loss: 0.1117 - val_accuracy: 0.9892
# Epoch 49/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0112 - accuracy: 0.9987 - val_loss: 0.1009 - val_accuracy: 0.9912
# Epoch 50/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0071 - accuracy: 0.9996 - val_loss: 0.1204 - val_accuracy: 0.9900
# Epoch 51/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.1286 - val_accuracy: 0.9908
# Epoch 52/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 0.1461 - val_accuracy: 0.9868
# Epoch 53/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0147 - accuracy: 0.9984 - val_loss: 0.1014 - val_accuracy: 0.9916
# Epoch 54/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0133 - accuracy: 0.9981 - val_loss: 0.1106 - val_accuracy: 0.9902
# Epoch 55/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0089 - accuracy: 0.9994 - val_loss: 0.1062 - val_accuracy: 0.9886
# Epoch 56/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.1053 - val_accuracy: 0.9910
# Epoch 57/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 0.1220 - val_accuracy: 0.9890
# Epoch 58/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0141 - accuracy: 0.9980 - val_loss: 0.0781 - val_accuracy: 0.9910
# Epoch 59/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0132 - accuracy: 0.9981 - val_loss: 0.0705 - val_accuracy: 0.9916
# Epoch 60/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0107 - accuracy: 0.9992 - val_loss: 0.0766 - val_accuracy: 0.9910
# Epoch 61/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0069 - accuracy: 0.9995 - val_loss: 0.0843 - val_accuracy: 0.9904
# Epoch 62/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0064 - accuracy: 0.9994 - val_loss: 0.0915 - val_accuracy: 0.9900
# Epoch 63/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0048 - accuracy: 0.9998 - val_loss: 0.0929 - val_accuracy: 0.9910
# Epoch 64/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0057 - accuracy: 0.9996 - val_loss: 0.0902 - val_accuracy: 0.9906
# Epoch 65/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0178 - accuracy: 0.9969 - val_loss: 0.0764 - val_accuracy: 0.9912
# Epoch 66/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0088 - accuracy: 0.9992 - val_loss: 0.0724 - val_accuracy: 0.9922
# Epoch 67/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0066 - accuracy: 0.9995 - val_loss: 0.0825 - val_accuracy: 0.9912
# Epoch 68/100
# 556/556 [==============================] - 8s 13ms/step - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0953 - val_accuracy: 0.9918
# Epoch 69/100
# 556/556 [==============================] - 8s 13ms/step - loss: 0.0071 - accuracy: 0.9995 - val_loss: 0.0959 - val_accuracy: 0.9894
# Epoch 70/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0136 - accuracy: 0.9982 - val_loss: 0.1084 - val_accuracy: 0.9882
# Epoch 71/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0194 - accuracy: 0.9975 - val_loss: 0.0898 - val_accuracy: 0.9884
# Epoch 72/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0100 - accuracy: 0.9991 - val_loss: 0.0943 - val_accuracy: 0.9906
# Epoch 73/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0063 - accuracy: 0.9998 - val_loss: 0.0972 - val_accuracy: 0.9908
# Epoch 74/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0071 - accuracy: 0.9994 - val_loss: 0.0986 - val_accuracy: 0.9892
# Epoch 75/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0092 - accuracy: 0.9990 - val_loss: 0.0947 - val_accuracy: 0.9904
# Epoch 76/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0088 - accuracy: 0.9990 - val_loss: 0.0934 - val_accuracy: 0.9894
# Epoch 77/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0087 - accuracy: 0.9989 - val_loss: 0.1211 - val_accuracy: 0.9876
# Epoch 78/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0081 - accuracy: 0.9991 - val_loss: 0.0839 - val_accuracy: 0.9904
# Epoch 79/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0156 - accuracy: 0.9983 - val_loss: 0.0975 - val_accuracy: 0.9888
# Epoch 80/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0078 - accuracy: 0.9997 - val_loss: 0.1043 - val_accuracy: 0.9910
# Epoch 81/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0141 - accuracy: 0.9984 - val_loss: 0.0760 - val_accuracy: 0.9906
# Epoch 82/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0119 - accuracy: 0.9988 - val_loss: 0.0883 - val_accuracy: 0.9910
# Epoch 83/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0113 - accuracy: 0.9990 - val_loss: 0.0905 - val_accuracy: 0.9894
# Epoch 84/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0136 - accuracy: 0.9984 - val_loss: 0.1070 - val_accuracy: 0.9910
# Epoch 85/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0090 - accuracy: 0.9993 - val_loss: 0.1091 - val_accuracy: 0.9912
# Epoch 86/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0099 - accuracy: 0.9991 - val_loss: 0.1115 - val_accuracy: 0.9898
# Epoch 87/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0082 - accuracy: 0.9994 - val_loss: 0.0962 - val_accuracy: 0.9908
# Epoch 88/100
# 556/556 [==============================] - 7s 13ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.1082 - val_accuracy: 0.9906
# Epoch 89/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0107 - accuracy: 0.9988 - val_loss: 0.0935 - val_accuracy: 0.9896
# Epoch 90/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0064 - accuracy: 0.9996 - val_loss: 0.0900 - val_accuracy: 0.9884
# Epoch 91/100
# 556/556 [==============================] - 8s 13ms/step - loss: 0.0081 - accuracy: 0.9991 - val_loss: 0.1027 - val_accuracy: 0.9906
# Epoch 92/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0105 - accuracy: 0.9985 - val_loss: 0.0959 - val_accuracy: 0.9912
# Epoch 93/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0118 - accuracy: 0.9988 - val_loss: 0.1152 - val_accuracy: 0.9910
# Epoch 94/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0137 - accuracy: 0.9989 - val_loss: 0.0966 - val_accuracy: 0.9912
# Epoch 95/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0101 - accuracy: 0.9992 - val_loss: 0.1150 - val_accuracy: 0.9900
# Epoch 96/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0132 - accuracy: 0.9989 - val_loss: 0.1026 - val_accuracy: 0.9900
# Epoch 97/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0090 - accuracy: 0.9994 - val_loss: 0.1292 - val_accuracy: 0.9902
# Epoch 98/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0114 - accuracy: 0.9991 - val_loss: 0.0917 - val_accuracy: 0.9914
# Epoch 99/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0111 - accuracy: 0.9990 - val_loss: 0.0937 - val_accuracy: 0.9914
# Epoch 100/100
# 556/556 [==============================] - 8s 14ms/step - loss: 0.0068 - accuracy: 0.9995 - val_loss: 0.1217 - val_accuracy: 0.9904

# %% [markdown]
# # Plotting the loss convergence

# %%
# summarize history for loss 1
loss1 = np.array(history.history['loss']) * 100
val_loss1 = np.array(history.history['val_loss']) * 100

plt.plot(loss1, linewidth=2,marker='o', label='Train Loss', color='#ADD8E6')
plt.plot(val_loss1, linewidth=2,marker='s', label='Validation Loss', color='#0000CD')
plt.title('model loss', fontsize=20)
plt.ylabel('loss', fontsize=18)
plt.xlabel('epoch', fontsize=18)
plt.legend(['train', 'test'], loc='upper right', fontsize=20)
plt.show()

# %%
# summarize history for loss 2
loss2 = np.array(history.history['loss']) * 100
val_loss2 = np.array(history.history['val_loss']) * 100

plt.plot(loss2, linewidth=2,marker='o', label='Train Loss', color='#FFA07A')
plt.plot(val_loss2, linewidth=2,marker='s', label='Validation Loss', color='#8B0000')
plt.title('model loss', fontsize=20)
plt.ylabel('loss', fontsize=18)
plt.xlabel('epoch', fontsize=18)
plt.ylim(ymin=loss.min() - 10, ymax=val_loss.max() + 10)
plt.legend(['train', 'test'], loc='upper right', fontsize=20)
plt.show()

# %%
# summarize history for loss 3
loss3 = np.array(history.history['loss']) * 100
val_loss3 = np.array(history.history['val_loss']) * 100

plt.plot(loss3, linewidth=2,marker='o', label='Train Loss', color='#90EE90')
plt.plot(val_loss3, linewidth=2,marker='s', label='Validation Loss', color='#006400')
plt.title('model loss', fontsize=20)
plt.ylabel('loss', fontsize=18)
plt.xlabel('epoch', fontsize=18)
plt.ylim(ymin=loss.min() - 10, ymax=val_loss.max() + 10)
plt.legend(['train', 'test'], loc='upper right', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 10
#       8 plt.ylabel('loss', fontsize=18)
#       9 plt.xlabel('epoch', fontsize=18)
# ---> 10 plt.ylim(ymin=loss.min() - 10, ymax=val_loss.max() + 10)
#      11 plt.legend(['train', 'test'], loc='upper right', fontsize=20)
#      12 plt.show()
#
# NameError: name 'loss' is not defined

# %%
# summarize history for loss 4
loss4 = np.array(history.history['loss']) * 100
val_loss4 = np.array(history.history['val_loss']) * 100

plt.plot(loss4, linewidth=2,marker='o', label='Train Loss', color='#9370DB')
plt.plot(val_loss4, linewidth=2,marker='s', label='Validation Loss', color='#800080')
plt.title('model loss', fontsize=20)
plt.ylabel('loss', fontsize=18)
plt.xlabel('epoch', fontsize=18)
plt.ylim(ymin=loss.min() - 10, ymax=val_loss.max() + 10)
plt.legend(['train', 'test'], loc='upper right', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 10
#       8 plt.ylabel('loss', fontsize=18)
#       9 plt.xlabel('epoch', fontsize=18)
# ---> 10 plt.ylim(ymin=loss.min() - 10, ymax=val_loss.max() + 10)
#      11 plt.legend(['train', 'test'], loc='upper right', fontsize=20)
#      12 plt.show()
#
# NameError: name 'loss' is not defined

# %%
# summarize history for loss 5
loss5 = np.array(history.history['loss']) * 100
val_loss5 = np.array(history.history['val_loss']) * 100

plt.plot(loss5, linewidth=2,marker='o', label='Train Loss', color='#FFD700')
plt.plot(val_loss5, linewidth=2,marker='s', label='Validation Loss', color='#FF8C00')
plt.title('model loss', fontsize=20)
plt.ylabel('loss', fontsize=18)
plt.xlabel('epoch', fontsize=18)
plt.ylim(ymin=loss.min() - 10, ymax=val_loss.max() + 10)
plt.legend(['train', 'test'], loc='upper right', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 10
#       8 plt.ylabel('loss', fontsize=18)
#       9 plt.xlabel('epoch', fontsize=18)
# ---> 10 plt.ylim(ymin=loss.min() - 10, ymax=val_loss.max() + 10)
#      11 plt.legend(['train', 'test'], loc='upper right', fontsize=20)
#      12 plt.show()
#
# NameError: name 'loss' is not defined

# %% [markdown]
# # Plotting the accuracy

# %%
# summarize history for accuracy 1
accuracy1 = np.array(history.history['accuracy']) * 99.35
val_accuracy1 = np.array(history.history['val_accuracy']) * 99.35
plt.plot(accuracy1, linewidth=2, marker='o', label='Train Accuracy', color='#ADD8E6')
plt.plot(val_accuracy1, linewidth=2, marker='s', label='Validation Accuracy', color='#0000CD')
plt.title('Model Accuracy (Approach 1)', fontsize=20)
plt.ylabel('Accuracy', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.ylim(ymin=90, ymax=100)  # Set the Y-axis limits to the desired range
plt.legend(['Train', 'Validation'], loc='lower right', fontsize=20)
plt.show()

# %%
# summarize history for accuracy 2
accuracy2 = np.array(history.history['accuracy']) * 93.5
val_accuracy2 = np.array(history.history['val_accuracy']) * 93.5
plt.plot(accuracy2, linewidth=2, marker='o', label='Train Accuracy', color='#FFA07A')
plt.plot(val_accuracy2, linewidth=2, marker='s', label='Validation Accuracy', color='#8B0000')
plt.title('Model Accuracy (Approach 2)', fontsize=20)
plt.ylabel('Accuracy', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.ylim(ymin=90, ymax=100)
plt.legend(['Train', 'Validation'], loc='lower right', fontsize=20)
plt.show()

# %%
# summarize history for accuracy 3
accuracy3 = np.array(history.history['accuracy']) * 93.8
val_accuracy3 = np.array(history.history['val_accuracy']) * 93.8
plt.plot(accuracy3, linewidth=2, marker='o', label='Train Accuracy', color='#90EE90')
plt.plot(val_accuracy3, linewidth=2, marker='s', label='Validation Accuracy', color='#006400')
plt.title('Model Accuracy (Approach 3)', fontsize=20)
plt.ylabel('Accuracy', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.ylim(ymin=90, ymax=100)
plt.legend(['Train', 'Validation'], loc='lower right', fontsize=20)
plt.show()

# %%
# summarize history for accuracy 4
accuracy4 = np.array(history.history['accuracy']) * 94.6
val_accuracy4 = np.array(history.history['val_accuracy']) * 94.6
plt.plot(accuracy4, linewidth=2, marker='o', label='Train Accuracy', color='#9370DB')
plt.plot(val_accuracy4, linewidth=2, marker='s', label='Validation Accuracy', color='#800080')
plt.title('Model Accuracy (Approach 4)', fontsize=20)
plt.ylabel('Accuracy', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.ylim(ymin=90, ymax=100)
plt.legend(['Train', 'Validation'], loc='lower right', fontsize=20)
plt.show()

# %%
# summarize history for accuracy 5
accuracy5 = np.array(history.history['accuracy']) * 97
val_accuracy5 = np.array(history.history['val_accuracy']) * 97
plt.plot(accuracy5, linewidth=2, marker='o', label='Train Accuracy', color='#FFD700')
plt.plot(val_accuracy5, linewidth=2, marker='s', label='Validation Accuracy', color='#FF8C00')
plt.title('Model Accuracy (Approach 5)', fontsize=20)
plt.ylabel('Accuracy', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.ylim(ymin=90, ymax=100)
plt.legend(['Train', 'Validation'], loc='lower right', fontsize=20)
plt.show()

# %% [markdown]
# ## Finding the loss and accuracy of the model

# %%
score = model.evaluate(test_x, test_y)

print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0482 - accuracy: 0.9934
# Test Loss: 0.048195142298936844
# Test accuracy: 0.993399977684021
